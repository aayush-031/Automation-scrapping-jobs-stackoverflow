# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
def pagination(n):
    driver = webdriver.Chrome()
    li_url=[]
    for i in range(1,n+1):
        url1='https://stackoverflow.com/jobs?pg='+str(i)
        driver.get(url1)
        obj=driver.find_elements_by_class_name('js-result ')
        dfs=pd.DataFrame()
        for o in obj:
            title=o.find_elements_by_tag_name('h2')
            for t in title:
                url= t.find_element_by_tag_name("a").get_attribute("href")
                li_url.append(url)
    driver.close()
    return li_url

# %%
def webpage_scrap(url1,n):
    driver = webdriver.Chrome()
    obj_dict={}
    driver.get(url1)
    try:
        salery=driver.find_element_by_class_name('fc-green-400').text
    except:
        salery="not defined"
    try:
        job_name=driver.find_element_by_class_name('fc-black-900').text
    except:
        job_name="not defined"
    try:
        com_name=driver.find_element_by_class_name('fc-black-800').text
    except:
        com_name="not defined"
    try:
        com_orign=driver.find_element_by_class_name('fc-black-500').text
    except:
        com_name="not defined"
    try:
        loc=driver.find_element_by_class_name('fc-yellow-500').text
    except:
        loc="not given"
    obj=driver.find_elements_by_class_name('mb32')
    about=obj[0:2]
    tag= []
    title=[]
    for o in about:
        j=o.find_elements_by_class_name('mb8')
        for i in j:
            try:
                t=i.find_element_by_tag_name('span').text
                tag.append(t)
                t2=i.find_element_by_class_name('fw-bold').text
                title.append(t2)
            except:
                tag.append("not given")
                title.append("not given")
    dictionary = dict(zip(tag, title))
    # print(df)
    obj.pop(0)
    obj.pop(0)
    techno= obj[0]
    obj.pop(0)
    try:
        tech=techno.find_elements_by_class_name('s-tag')
    except:
        tech="not"
    desc=obj[0]
    obj.pop(0)
    d=desc.find_element_by_tag_name('div').text
    apply=obj[0]
    try:
        app_link=apply.find_element_by_tag_name("a").get_attribute("href")
    except:
        app_link="not given"
    obj_dict[n]={
        "Salary" :salery,
        "Job_title":job_name,
        "Company_name":com_name,
        "Location":loc,
        "Technology/Framework": ",".join([_.text for _ in tech]),
        "Description":d,
        "Apply_link":app_link,
        "url":url1,  
    }
    df = pd.DataFrame(obj_dict).T
    df = df.replace(r'\n',' ', regex=True)
    dfs = pd.DataFrame.from_records([dictionary])
    dfs= dfs.reset_index()
    result = pd.concat([df,dfs], axis=1, join='inner')
    result.drop(['index'],axis=1,inplace=True)
    driver.close()
    return result

# %%
driver = webdriver.Chrome()
url1='https://stackoverflow.com/jobs'
driver.get(url1)
j = driver.find_element_by_class_name('s-pagination').find_elements_by_tag_name("a")
page_no=int(j[-2].text)
driver.close()
li_url = pagination(page_no)

# %%
dfs=pd.DataFrame()
ddfs=pd.DataFrame()
n=0
for i in li_url:
    df=webpage_scrap(i,n)
    dfs=dfs.append(df)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-12-6641dac062ec> in <module>
#       3 n=0
#       4 for i in li_url:
# ----> 5     df=webpage_scrap(i,n)
#       6     dfs=dfs.append(df)
#
# <ipython-input-3-8f18bd625858> in webpage_scrap(url1, n)
#       2     driver = webdriver.Safari()
#       3     obj_dict={}
# ----> 4     driver.get(url1)
#       5     try:
#       6         salery=driver.find_element_by_class_name('fc-green-400').text
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message:

# %%
dfs
# Out:
#                                          Description  \
# 0   How we work eyeo colleagues are based all ove...
# 0                                                ...
# 0   About Jibble Group We’re a scale-up in the Wo...
# 0                                                ...
# 0                                                ...
# 0                                                ...
# 0   Job Description: We are looking for a Team Le...
# 0   Hubbers are doers, makers and hackers.At Hubs...
# 0   Goodgame Studios is a leading free-to-play, o...
# 0                                                ...
# 0                                                ...
# 0    Full-time permanent role Based remotely, fro...
# 0                                                ...
# 0                                                ...
#
#                                           apply_link  \
# 0  https://stackoverflow.com/jobs/apply/509364?ra...
# 0                                          not given
# 0  https://jibble-group.breezy.hr/p/61c48ba159e30...
# 0                      https://www.codapayments.com/
# 0                                          not given
# 0                                          not given
# 0  https://hiring.selfdecode.com/jobs/71af6982-01...
# 0  https://jobs.lever.co/3dhubs/1f405221-7660-466...
# 0  https://jobs.lever.co/goodgamestudios/866b4584...
# 0  https://x-team.com/?utm_source=stackoverflow&u...
# 0                              http://wordpress.com/
# 0  https://stackoverflow.com/jobs/apply/523004?ra...
# 0  https://x-team.com/?utm_source=stackoverflow&u...
# 0                          https://www.bitfinex.com/
#
#                                         company_name  \
# 0                        DevOps Engineer
# 0   Data Engineer at sustainable mobility start-u...
# 0                                             Jibble
# 0                Technical Lead (Vue.js)
# 0        Senior Golang Software Engineer
# 0      QA / DevOps Engineer (Kubernetes)
# 0                Chief Technical Officer
# 0   Senior Frontend Engineer - Employee Performan...
# 0                Backend/DevOps Engineer
# 0              Vue.js Developer (Remote)
# 0   Backend Software Engineer, PHP (Remote)      ...
# 0   Lead Polyglot Software Engineers – TDD, XP, J...
# 0   Full-Stack JavaScript Developer (Remote)     ...
# 0      Remote Senior Front End Developer
#
#                                             job_name  \
# 0         Software Engineer for AdblockPlus Chromium
# 0  VP Engineering at mobility start-up (m/f/x) - ...
# 0                               Full Stack Developer
# 0                    Senior/Front End Engineer, APAC
# 0                  QA / DevOps Engineer (Kubernetes)
# 0                    Senior Golang Software Engineer
# 0          Software Architect (Django/Flask + React)
# 0                 Backend Software Engineer - Python
# 0     Freelance Java Backend Developer (all genders)
# 0           Full-Stack JavaScript Developer (Remote)
# 0                  Systems Engineer at WordPress VIP
# 0  Remote Polyglot Software Engineer – TDD, XP, J...
# 0                          Vue.js Developer (Remote)
# 0           Senior Backend Developer - Node (Remote)
#
#                      location                                     salary  \
# 0                      Remote                                not defined
# 0                      Remote                      €100k - 125k | Equity
# 0                      Remote                                 $48k - 60k
# 0                      Remote                                not defined
# 0                      Remote                                not defined
# 0                      Remote                                not defined
# 0                      Remote                                $60k - 100k
# 0  On-site and limited remote                        €45k - 65k | Equity
# 0                      Remote
# 0                      Remote                                not defined
# 0                      Remote                                not defined
# 0                      Remote                                 $40k - 80k
# 0                      Remote                                not defined
# 0                      Remote                                not defined
#
#                                   techno  \
# 0           c++,java,chromium,javascript
# 0
# 0          .net,c#,postgresql,vue.js,api
# 0
# 0
# 0
# 0       reactjs,python,javascript,django
# 0              python,postgresql,reactjs
# 0   java,spring,mysql,aws-lambda,node.js
# 0
# 0
# 0  javascript,reactjs,node.js,kotlin,tdd
# 0
# 0
#
#                                                  url Job type:   \
# 0  https://stackoverflow.com/jobs/509364/software...  Full-time
# 0  https://stackoverflow.com/jobs/445056/vp-engin...  Full-time
# 0  https://stackoverflow.com/jobs/557756/full-sta...  Full-time
# 0  https://stackoverflow.com/jobs/557316/senior-f...  Full-time
# 0  https://stackoverflow.com/jobs/552137/qa-devop...  Full-time
# 0  https://stackoverflow.com/jobs/550557/senior-g...  Full-time
# 0  https://stackoverflow.com/jobs/307459/software...  Full-time
# 0  https://stackoverflow.com/jobs/543394/backend-...  Full-time
# 0  https://stackoverflow.com/jobs/554534/freelanc...   Contract
# 0  https://stackoverflow.com/jobs/534446/full-sta...  Full-time
# 0  https://stackoverflow.com/jobs/556113/systems-...  Full-time
# 0  https://stackoverflow.com/jobs/523004/remote-p...  Full-time
# 0  https://stackoverflow.com/jobs/534462/vuejs-de...  Full-time
# 0  https://stackoverflow.com/jobs/556300/senior-b...  Full-time
#
#         Experience level:                                          Industry:   \
# 0        Mid-Level, Senior       Mobile, Product Development, Web Development
# 0            Lead, Manager   Agile Software Development, Automotive, Mobility
# 0                Mid-Level                                                NaN
# 0        Mid-Level, Senior              Financial Technology, Mobile Payments
# 0                Mid-Level  Databases, DBaaS, Software Development / Engin...
# 0                   Senior  Databases, DBaaS, Software Development / Engin...
# 0    Senior, Lead, Manager  Bioinformatics, Computer Software, Digital Health
# 0        Mid-Level, Senior                   3D Printing, Manufacturing, SaaS
# 0        Mid-Level, Senior                                             Gaming
# 0  Mid-Level, Senior, Lead                               Software Development
# 0  Mid-Level, Senior, Lead                              eCommerce, Publishing
# 0             Senior, Lead  Product Development, Software Development / En...
# 0  Mid-Level, Senior, Lead                               Software Development
# 0                   Senior  Cryptocurrency, Financial Services, Financial ...
#
#    Company size:  Company type:   \
# 0  201-500 people        Private
# 0   51-200 people      VC Funded
# 0             NaN            NaN
# 0  201-500 people      VC Funded
# 0  201-500 people        Private
# 0  201-500 people        Private
# 0    11-50 people        Private
# 0   51-200 people         Public
# 0  201-500 people        Private
# 0  201-500 people        Private
# 0    1k-5k people        Private
# 0    11-50 people        Private
# 0  201-500 people        Private
# 0   51-200 people        Private
#
#                                  Preferred Timezone:  \
# 0                     (GMT+01:00) Berlin +/- 4 hours
# 0                                                NaN
# 0                    (GMT+04:00) Yerevan +/- 4 hours
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                      (GMT+03:00) Minsk +/- 8 hours
# 0                                                NaN
# 0                     (GMT+01:00) Berlin +/- 2 hours
# 0                                                NaN
# 0                                                NaN
# 0  (GMT+11:00) Eastern Time - Melbourne, Sydney +...
# 0                                                NaN
# 0                                                NaN
#
#                                               Role:   \
# 0                                                NaN
# 0                                                NaN
# 0  Backend Developer, Frontend Developer, Full St...
# 0              Backend Developer, Frontend Developer
# 0                          DevOps, QA/Test Developer
# 0                                                NaN
# 0                                                NaN
# 0                                  Backend Developer
# 0                                  Backend Developer
# 0                               Full Stack Developer
# 0                       DevOps, System Administrator
# 0                                                NaN
# 0                                 Frontend Developer
# 0                                  Backend Developer
#
#                                     Employer's note: Visa Sponsorship:  \
# 0                                                NaN               NaN
# 0                                                NaN               NaN
# 0                                                NaN               NaN
# 0                                                NaN               NaN
# 0                                                NaN               NaN
# 0                                                NaN               NaN
# 0                                                NaN               NaN
# 0  Employees are able to work hybrid, 2-3 days at...               Yes
# 0                                                NaN               NaN
# 0                                                NaN               NaN
# 0                                                NaN               NaN
# 0                                                NaN               NaN
# 0                                                NaN               NaN
# 0                                                NaN               NaN
#
#   Relocation Assistance:
# 0                    NaN
# 0                    NaN
# 0                    NaN
# 0                    NaN
# 0                    NaN
# 0                    NaN
# 0                    NaN
# 0                    Yes
# 0                    NaN
# 0                    NaN
# 0                    NaN
# 0                    NaN
# 0                    NaN
# 0                    NaN

# %%
dfs.to_pickle("stackOverflow_jobs.pkl")
